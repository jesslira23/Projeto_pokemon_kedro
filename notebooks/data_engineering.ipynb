# %%
pp_pokemon = catalog.load('pp_pokemon_dataset')
pp_pokemon
# Out:
# 2022-05-07 11:19:02,173 - kedro.io.data_catalog - INFO - Loading data from `pp_pokemon_dataset` (CSVDataSet)...
#                                       abilities  against_bug  against_dark  \
# 0                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3                      ['Blaze', 'Solar Power']          0.5           1.0
# 4                      ['Blaze', 'Solar Power']          0.5           1.0
# ..                                          ...          ...           ...
# 679  ['Dazzling', 'Strong Jaw', 'Wonder Skin ']          2.0           2.0
# 680     ['Berserk', 'Sap Sipper', 'Cloud Nine']          1.0           1.0
# 681   ['Bulletproof', 'Soundproof', 'Overcoat']          1.0           1.0
# 682   ['Bulletproof', 'Soundproof', 'Overcoat']          0.5           0.5
# ...

# %%
pp_pokemon['type1']
#variavel descritiva
#transformar pra numeros 
#usar o lable uncouder
# Out:
# 0       grass
# 1       grass
# 2       grass
# 3        fire
# 4        fire
#         ...
# 679     water
# 680    normal
# 681    dragon
# 682    dragon
# 683    dragon
# Name: type1, Length: 684, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
label_encoder
# Out:
# LabelEncoder()

# %%
label_encoder = label_encoder.fit(pp_pokemon['type1'])

# %%
pp_pokemon['type1'] = label_encoder.transform(pp_pokemon['type1'])

# %%
label_encoder.inverse_transform(pp_pokemon['type1'])
# Out:
# array(['grass', 'grass', 'grass', 'fire', 'fire', 'fire', 'water',
#        'water', 'water', 'bug', 'bug', 'bug', 'bug', 'bug', 'bug',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'poison',
#        'poison', 'electric', 'poison', 'poison', 'poison', 'poison',
#        'poison', 'poison', 'fairy', 'fairy', 'normal', 'normal', 'poison',
#        'poison', 'grass', 'grass', 'grass', 'bug', 'bug', 'bug', 'bug',
#        'water', 'water', 'fighting', 'fighting', 'fire', 'fire', 'water',
#        'water', 'water', 'psychic', 'psychic', 'psychic', 'fighting',
#        'fighting', 'fighting', 'grass', 'grass', 'grass', 'water',
#        'water', 'fire', 'fire', 'water', 'water', 'normal', 'normal',
#        'normal', 'water', 'water', 'water', 'water', 'ghost', 'ghost',
#        'ghost', 'rock', 'psychic', 'psychic', 'water', 'water', 'grass',
#        'ground', 'fighting', 'fighting', 'normal', 'poison', 'poison',
# ...
