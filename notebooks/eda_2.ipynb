# %%
from sklearn.model_selection import train_test_split

# %%
catalog.list()
# Out:
# ['raw_pokemon_dataset',
#  'pp_pokemon_dataset',
#  'encode_pokemon_dataset',
#  'pokemon_features',
#  'label_encoder',
#  'parameters',
#  'params:selected_generation']

# %%
df = catalog.load('pokemon_features')
df
# Out:
# 2022-05-09 20:21:28,098 - kedro.io.data_catalog - INFO - Loading data from `pokemon_features` (CSVDataSet)...
#                                       abilities  against_bug  against_dark  \
# 0                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3                      ['Blaze', 'Solar Power']          0.5           1.0
# 4                      ['Blaze', 'Solar Power']          0.5           1.0
# ..                                          ...          ...           ...
# 679  ['Dazzling', 'Strong Jaw', 'Wonder Skin ']          2.0           2.0
# 680     ['Berserk', 'Sap Sipper', 'Cloud Nine']          1.0           1.0
# 681   ['Bulletproof', 'Soundproof', 'Overcoat']          1.0           1.0
# 682   ['Bulletproof', 'Soundproof', 'Overcoat']          0.5           0.5
# ...

# %%
df.dtypes
# Out:
# abilities               object
# against_bug            float64
# against_dark           float64
# against_dragon         float64
# against_electric       float64
# against_fairy          float64
# against_fight          float64
# against_fire           float64
# against_flying         float64
# against_ghost          float64
# against_grass          float64
# against_ground         float64
# against_ice            float64
# against_normal         float64
# against_poison         float64
# against_psychic        float64
# against_rock           float64
# against_steel          float64
# against_water          float64
# attack                   int64
# base_egg_steps           int64
# base_happiness           int64
# base_total               int64
# capture_rate             int64
# classfication           object
# defense                  int64
# experience_growth        int64
# height_m               float64
# hp                       int64
# japanese_name           object
# ...

# %%
against_cols = [col for col in df if col.startswith('against')]
against_cols
# Out:
# ['against_bug',
#  'against_dark',
#  'against_dragon',
#  'against_electric',
#  'against_fairy',
#  'against_fight',
#  'against_fire',
#  'against_flying',
#  'against_ghost',
#  'against_grass',
#  'against_ground',
#  'against_ice',
#  'against_normal',
#  'against_poison',
#  'against_psychic',
#  'against_rock',
#  'against_steel',
#  'against_water']

# %%
numerical_starts_columns = [
    'base_total', 'attack', 'defense', 'hp', 'sp_attack', 'sp_defense', 'speed', 'height_m', 'weight_kg', 'number_of_abilities'
]

numerical_starts_columns
# Out:
# ['base_total',
#  'attack',
#  'defense',
#  'hp',
#  'sp_attack',
#  'sp_defense',
#  'speed',
#  'height_m',
#  'weight_kg',
#  'number_of_abilities']

# %%
cols_to_select = against_cols + numerical_starts_columns + ['type1']
cols_to_select
# Out:
# ['against_bug',
#  'against_dark',
#  'against_dragon',
#  'against_electric',
#  'against_fairy',
#  'against_fight',
#  'against_fire',
#  'against_flying',
#  'against_ghost',
#  'against_grass',
#  'against_ground',
#  'against_ice',
#  'against_normal',
#  'against_poison',
#  'against_psychic',
#  'against_rock',
#  'against_steel',
#  'against_water',
#  'base_total',
#  'attack',
#  'defense',
#  'hp',
#  'sp_attack',
#  'sp_defense',
#  'speed',
#  'height_m',
#  'weight_kg',
#  'number_of_abilities',
#  'type1']

# %%
df = df[cols_to_select]
df.dtypes
# Out:
# against_bug            float64
# against_dark           float64
# against_dragon         float64
# against_electric       float64
# against_fairy          float64
# against_fight          float64
# against_fire           float64
# against_flying         float64
# against_ghost          float64
# against_grass          float64
# against_ground         float64
# against_ice            float64
# against_normal         float64
# against_poison         float64
# against_psychic        float64
# against_rock           float64
# against_steel          float64
# against_water          float64
# base_total               int64
# attack                   int64
# defense                  int64
# hp                       int64
# sp_attack                int64
# sp_defense               int64
# speed                    int64
# height_m               float64
# weight_kg              float64
# number_of_abilities      int64
# type1                    int64
# dtype: object

# %%
# Split train and test

X = df.drop('type1', axis=1)
y = df['type1']

#matriz = letra maiuscula
#vetor = letra minuscula

# %%
X_train, X_test, y_train, y_test =  train_test_split(
    X, y, test_size = 0.3, random_state=9999, stratify = y
)

# %%
X_train
# Out:
#      against_bug  against_dark  against_dragon  against_electric  \
# 177          0.5           0.5             0.0               1.0
# 557          0.5           1.0             1.0               1.0
# 286          1.0           1.0             1.0               1.0
# 111          1.0           1.0             1.0               2.0
# 512          2.0           1.0             1.0               0.5
# ..           ...           ...             ...               ...
# 671          1.0           1.0             1.0               2.0
# 451          1.0           1.0             1.0               1.0
# 187          1.0           1.0             1.0               0.0
# 494          0.5           1.0             1.0               1.0
# 283          0.5           1.0             1.0               1.0
#
#      against_fairy  against_fight  against_fire  against_flying  \
# 177            1.0            0.5          1.00             1.0
# ...

# %%
from sklearn import tree

classifier = tree.DecisionTreeClassifier()
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred = classifier.predict(X_test)

score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.8883495145631068

# %%
def split_data(df, test_size = 0.3, random_state=9999):
    """Splits data into train and test dataset"""
    
    X_train, X_test, y_train, y_test =  train_test_split(
    X, y, test_size = 0.3, random_state=9999, stratify = y
    )
    
    return X_train, X_test, y_train, y_test
    
    

def fit_model(X_train, X_test, y_test):
    """ Fits a classifier model using a training dataset    """
   
    classifier = tree.DecisionTreeClassifier()
    classifier.fit(X_train,y_train)
    
    # Predict test set
    y_pred = classifier.predict(X_test)

    #Reports Score
    score = accuracy_score(y_test, y_pred)
    print(score)

    return classifier

# %%
X_train, X_test, y_train, y_test = split_data(df)

# %%
fit_model(X_train, X_test, y_test)
# Out:
# 0.8883495145631068
# DecisionTreeClassifier()
