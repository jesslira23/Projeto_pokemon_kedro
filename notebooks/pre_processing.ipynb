# %%
import pandas as pd

# %%
catalog.list()
# Out:
# ['raw_pokemon_dataset', 'pre_processed_data', 'parameters']

# %%
df = catalog.load('raw_pokemon_dataset')
# Out:
# 2022-05-07 10:35:16,829 - kedro.io.data_catalog - INFO - Loading data from `raw_pokemon_dataset` (CSVDataSet)...

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
#verifying columns with null values
nan_df = df.isnull().sum()
nan_df
# Out:
# abilities              0
# against_bug            0
# against_dark           0
# against_dragon         0
# against_electric       0
# against_fairy          0
# against_fight          0
# against_fire           0
# against_flying         0
# against_ghost          0
# against_grass          0
# against_ground         0
# against_ice            0
# against_normal         0
# against_poison         0
# against_psychic        0
# against_rock           0
# against_steel          0
# against_water          0
# attack                 0
# base_egg_steps         0
# base_happiness         0
# base_total             0
# capture_rate           0
# classfication          0
# defense                0
# experience_growth      0
# height_m              20
# hp                     0
# japanese_name          0
# name                   0
# percentage_male       98
# pokedex_number         0
# sp_attack              0
# sp_defense             0
# speed                  0
# type1                  0
# ...

# %%
#droping unused columns 
drop_columns_df = df.drop(columns=['type2','pokedex_number'])
drop_columns_df.isnull().sum()
# Out:
# abilities             0
# against_bug           0
# against_dark          0
# against_dragon        0
# against_electric      0
# against_fairy         0
# against_fight         0
# against_fire          0
# against_flying        0
# against_ghost         0
# against_grass         0
# against_ground        0
# against_ice           0
# against_normal        0
# against_poison        0
# against_psychic       0
# against_rock          0
# against_steel         0
# against_water         0
# attack                0
# base_egg_steps        0
# base_happiness        0
# base_total            0
# capture_rate          0
# classfication         0
# defense               0
# experience_growth     0
# height_m             20
# hp                    0
# japanese_name         0
# name                  0
# percentage_male      98
# sp_attack             0
# sp_defense            0
# speed                 0
# type1                 0
# weight_kg            20
# generation            0
# ...

# %%
#Droping lines with NaN
drop_df = drop_columns_df.dropna()
drop_df.isnull().sum()
# Out:
# abilities            0
# against_bug          0
# against_dark         0
# against_dragon       0
# against_electric     0
# against_fairy        0
# against_fight        0
# against_fire         0
# against_flying       0
# against_ghost        0
# against_grass        0
# against_ground       0
# against_ice          0
# against_normal       0
# against_poison       0
# against_psychic      0
# against_rock         0
# against_steel        0
# against_water        0
# attack               0
# base_egg_steps       0
# base_happiness       0
# base_total           0
# capture_rate         0
# classfication        0
# defense              0
# experience_growth    0
# height_m             0
# hp                   0
# japanese_name        0
# name                 0
# percentage_male      0
# pokedex_number       0
# sp_attack            0
# sp_defense           0
# speed                0
# type1                0
# weight_kg            0
# generation           0
# is_legendary         0
# ...

# %%
def pre_processing(df:pd.DataFrame, selected_generation=[1]):
    """
    Function to clean the data (drop the unused columns and drop NaN values)

        Args: pokemon raw dataset
        Returns: pre_processed data

    """
    #Remove unused columns
    df = df.drop(columns=['type2','pokedex_number'])
    
    #Remove null valous
    df = df.dropna()
    
    #Select Generation
    df = df[df.generation.isin(selected_generation)]
    
    return df

# %%
#Test function

df_cleaned = pre_processing(catalog.load('raw_pokemon_dataset'))
df_cleaned
# Out:
# 2022-05-07 10:57:04,575 - kedro.io.data_catalog - INFO - Loading data from `raw_pokemon_dataset` (CSVDataSet)...
#                                  abilities  against_bug  against_dark  \
# 0              ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1              ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2              ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3                 ['Blaze', 'Solar Power']          0.5           1.0
# 4                 ['Blaze', 'Solar Power']          0.5           1.0
# ..                                     ...          ...           ...
# 141   ['Rock Head', 'Pressure', 'Unnerve']          0.5           1.0
# 142  ['Immunity', 'Thick Fat', 'Gluttony']          1.0           1.0
# 146          ['Shed Skin', 'Marvel Scale']          1.0           1.0
# 147          ['Shed Skin', 'Marvel Scale']          1.0           1.0
# 148          ['Inner Focus', 'Multiscale']          0.5           1.0
#
# ...

# %%
pre_processing(catalog.load('raw_pokemon_dataset'))
# Out:
# 2022-04-26 20:46:21,988 - kedro.io.data_catalog - INFO - Loading data from `raw_pokemon_dataset` (CSVDataSet)...
#                                       abilities  against_bug  against_dark  \
# 0                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2                   ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3                      ['Blaze', 'Solar Power']          0.5           1.0
# 4                      ['Blaze', 'Solar Power']          0.5           1.0
# ..                                          ...          ...           ...
# 778  ['Dazzling', 'Strong Jaw', 'Wonder Skin ']          2.0           2.0
# 779     ['Berserk', 'Sap Sipper', 'Cloud Nine']          1.0           1.0
# 781   ['Bulletproof', 'Soundproof', 'Overcoat']          1.0           1.0
# 782   ['Bulletproof', 'Soundproof', 'Overcoat']          0.5           0.5
# ...

# %%
df.groupby(['generation']).nunique()
# Out:
#             abilities  against_bug  against_dark  against_dragon  \
# generation
# 1                  96            5             3               4
# 2                  74            5             3               4
# 3                  86            5             3               4
# 4                  74            4             3               4
# 5                  92            4             4               4
# 6                  44            5             5               4
# 7                  54            4             4               4
#
#             against_electric  against_fairy  against_fight  against_fire  \
# generation
# 1                          5              3              5             5
# 2                          5              3              6             5
# 3                          5              3              6             4
# 4                          5              4              6             5
# ...

# %%
df_selected = df[df.generation.isin([1])]
df_selected
# Out:
#                          abilities  against_bug  against_dark  against_dragon  \
# 0      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2      ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4         ['Blaze', 'Solar Power']          0.5           1.0             1.0
# ..                             ...          ...           ...             ...
# 146  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 147  ['Shed Skin', 'Marvel Scale']          1.0           1.0             2.0
# 148  ['Inner Focus', 'Multiscale']          0.5           1.0             2.0
# 149        ['Pressure', 'Unnerve']          2.0           2.0             1.0
# 150                ['Synchronize']          2.0           2.0             1.0
#
# ...
